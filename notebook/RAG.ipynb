# %%
! uv pip install langchain openai tiktoken rapidocr-onnxruntime python-dotenv langchain-community
# Out:
# Using Python 3.13.7 environment at: C:\Users\user\recap-coding-practice\llmops\.venv
# Resolved 72 packages in 5.46s
# Downloading opencv-python (38.3MiB)
# Downloading shapely (1.6MiB)
# Downloading numpy (11.7MiB)
# Downloading openai (1.1MiB)
# Downloading langchain-community (2.4MiB)
# Downloading onnxruntime (12.0MiB)
# Downloading rapidocr-onnxruntime (14.2MiB)
# Downloading pillow (6.7MiB)
#  Downloading shapely
#  Downloading pillow
#  Downloading rapidocr-onnxruntime
#  Downloading onnxruntime
#  Downloading numpy
#  Downloading opencv-python
#  Downloading openai
#  Downloading langchain-community
# Prepared 24 packages in 41.27s
# Installed 68 packages in 30.59s
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.4
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anyio==4.13.0
#  + attrs==26.1.0
#  + certifi==2026.2.25
#  + charset-normalizer==3.4.6
#  + dataclasses-json==0.6.7
#  + distro==1.9.0
#  + flatbuffers==25.12.19
#  + frozenlist==1.8.0
#  + greenlet==3.3.2
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + httpx-sse==0.4.3
#  + idna==3.11
#  + jiter==0.13.0
#  + jsonpatch==1.33
#  + jsonpointer==3.1.1
#  + langchain==1.2.13
#  + langchain-classic==1.0.3
#  + langchain-community==0.4.1
#  + langchain-core==1.2.23
#  + langchain-text-splitters==1.1.1
#  + langgraph==1.1.3
#  + langgraph-checkpoint==4.0.1
#  + langgraph-prebuilt==1.0.8
#  + langgraph-sdk==0.3.12
#  + langsmith==0.7.22
#  + marshmallow==3.26.2
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + mypy-extensions==1.1.0
#  + numpy==2.4.4
#  + onnxruntime==1.24.4
#  + openai==2.30.0
#  + opencv-python==4.13.0.92
#  + orjson==3.11.7
#  + ormsgpack==1.12.2
#  + pillow==12.1.1
#  + propcache==0.4.1
#  + protobuf==7.34.1
#  + pyclipper==1.4.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pydantic-settings==2.13.1
#  + pyyaml==6.0.3
#  + rapidocr-onnxruntime==1.4.4
#  + regex==2026.3.32
#  + requests==2.33.1
#  + requests-toolbelt==1.0.0
#  + shapely==2.1.2
#  + sniffio==1.3.1
#  + sqlalchemy==2.0.48
#  + sympy==1.14.0
#  + tenacity==9.1.4
#  + tiktoken==0.12.0
#  + tqdm==4.67.3
#  + typing-extensions==4.15.0
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + uuid-utils==0.14.1
#  + xxhash==3.6.0
#  + yarl==1.23.0
#  + zstandard==0.25.0

# %%
import os

from dotenv import load_dotenv

load_dotenv()


os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
! uv pip install faiss-cpu
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'llmops (3.13.7) (Python 3.13.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
